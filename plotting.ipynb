# %%
from utils import *
from distributions import nvals

df_loaded = load_results(4096)

plot_from_results_df(nvals, df_loaded)
# Out:
# Saved plot as plots/gaussian.pdf
# Saved plot as plots/bimodal_gaussian.pdf
# Saved plot as plots/cosine.pdf
# Saved plot as plots/sine.pdf
# Saved plot as plots/exponential.pdf
# Saved plot as plots/logarithmic.pdf
# Saved plot as plots/dirac_delta_spikes.pdf
# Saved plot as plots/uniform.pdf
# Saved plot as plots/step_function.pdf
# Saved plot as plots/parabolic_dist..pdf
