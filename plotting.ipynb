# %%
from utils import *
from distributions import nvals

df_loaded = load_results(1024, folder='caching_dp')

plot_from_results_df(nvals, df_loaded, x='n', data_name='Column')
# Out:
# /home/ec2-user/cheb_match_clones/clone_1/PafnutyMatch/utils.py:92: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(data=df[df[data_name] == distribution], x=x, y='Wasserstein Distance', ci='sd', estimator='mean', linewidth=2.5, label='Alg. 2')
# Saved plot as plots/gaussian.pdf
# /home/ec2-user/cheb_match_clones/clone_1/PafnutyMatch/utils.py:92: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(data=df[df[data_name] == distribution], x=x, y='Wasserstein Distance', ci='sd', estimator='mean', linewidth=2.5, label='Alg. 2')
# Saved plot as plots/sine.pdf
# /home/ec2-user/cheb_match_clones/clone_1/PafnutyMatch/utils.py:92: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(data=df[df[data_name] == distribution], x=x, y='Wasserstein Distance', ci='sd', estimator='mean', linewidth=2.5, label='Alg. 2')
# ...
